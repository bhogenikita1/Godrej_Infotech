# %%
##14/01/2025

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#catogorical

# %% [markdown]
# # Barplot
#
# compare catogories

# %%
sns.barplot(data=tips,x="smoker",y="total_bill")
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %%
sns.barplot(tips,x="smoker",y="total_bill",estimator=sum)
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %%
sns.barplot(tips,x="time",y="total_bill",estimator=sum)
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
sns.barplot(data=tips,x="sex",y="tip",estimator=min)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.barplot(data=tips,x="day",y="total_bill",estimator="sum")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(data=tips,x="day",y="total_bill",estimator="sum",hue="smoker")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(data=tips,x="day",y="total_bill",estimator="sum",hue="time")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(data=tips,x="day",y="total_bill",estimator="sum",hue="time",palette="rainbow")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(data=tips,x="size",y="total_bill",estimator="sum")
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
sns.barplot(data=tips,x="size",y="total_bill",estimator="sum",hue="sex")
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
sns.barplot(data=tips,x="size",y="total_bill",estimator="sum",hue="smoker")
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %% [markdown]
#  # count plot

# %%
sns.countplot(data=tips,x="sex")
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(data=tips,x="smoker",hue="time")
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(data=tips,y="smoker",hue="time")
# Out:
# <Axes: xlabel='count', ylabel='smoker'>

# %%
sns.countplot(data=tips,x='day',palette='Set1')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15316\3391118781.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=tips,x='day',palette='Set1')
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(data=tips,x="day",hue="size",palette="Set2")
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(data=tips,y="day",hue="size",palette="Set1")
# Out:
# <Axes: xlabel='count', ylabel='day'>

# %% [markdown]
# # Boxplot

# %%
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
sns.boxplot(data=tips,x="day",y="total_bill")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(tips["total_bill"])
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.boxplot(data=tips,x="day",y="total_bill",palette="Set1")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15316\1262122295.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=tips,x="day",y="total_bill",palette="Set1")
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sum(tips["day"]=="Thur")
#there are 16 customers out of 62 who visited on thur are less than or equal to 12 dollars
# Out:
# 62

# %%
tips["day"]
# Out:
# 0       Sun
# 1       Sun
# 2       Sun
# 3       Sun
# 4       Sun
#        ...
# 239     Sat
# 240     Sat
# 241     Sat
# 242     Sat
# 243    Thur
# Name: day, Length: 244, dtype: category
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
sns.boxplot(data=tips,x="day",y="total_bill",hue="time")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=tips,x="day",y="total_bill",hue="smoker")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x=tips["total_bill"])
# Out:
# <Axes: xlabel='total_bill'>

# %% [markdown]
# # Violinplot

# %%
sns.violinplot(data=tips,x="day",y="total_bill",palette="Set2")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15316\2875163219.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=tips,x="day",y="total_bill",palette="Set2")
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(data=tips,x="day",y="total_bill",hue="smoker")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(data=tips,x="day",y="total_bill",hue="smoker",split=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(data=tips,x="day",y="total_bill",hue="sex",split=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # stripplot

# %%
sns.stripplot(data=tips,x="day",y="total_bill")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(data=tips,x="day",y="total_bill",jitter=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(data=tips,x="day",y="total_bill",jitter=False)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(data=tips,x="day",y="total_bill",hue="smoker")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(data=tips,x="day",y="total_bill",hue="smoker",dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x="day",y="total_bill",data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x="day",y="total_bill",data=tips,hue="time")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="tip", y="day", data=tips,palette='rainbow')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15316\1688413987.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="tip", y="day", data=tips,palette='rainbow')
# <Axes: xlabel='tip', ylabel='day'>

# %%
sns.swarmplot(x="tip", y="day", data=tips,color='black',size=3)
# Out:
# <Axes: xlabel='tip', ylabel='day'>
